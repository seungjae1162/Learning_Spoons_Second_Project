# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
datalab = pd.read_csv("data/datalab.csv")
datalab.head(3)
sin = pd.read_csv("data/sin.csv")
sin.head(3)
jp = pd.read_csv("data/japan.csv")

# %%
sin.dtypes
# Out:
# Date     object
# Surf    float64
# dtype: object

# %%
datalab_date = pd.to_datetime(datalab.Date)
datalab_date.dtypes
sin_date = pd.to_datetime(sin.Date)
jp_date = pd.to_datetime(jp.Date)

# %%
datalab = datalab.set_index('Date')
sin = sin.set_index('Date')
jp = jp.set_index('Date')

# %%
sin
# Out:
#                 Surf
# Date
# 2019-03-01   0.09863
# 2019-03-02   0.09333
# 2019-03-03   0.10466
# 2019-03-04   0.08927
# 2019-03-05   0.08289
# ...              ...
# 2020-02-26  78.68609
# 2020-02-27  75.55923
# 2020-02-28  70.34025
# 2020-02-29  61.34314
# 2020-03-01  54.56533
#
# [367 rows x 1 columns]

# %%
mask_g = datalab['Surf'].plot(title = 'Surf')
sin_g = sin['Surf'].plot()
jp_g = jp['Surf'].plot()
fig = mask_g.get_figure()
fig.set_size_inches(13.5,9)
